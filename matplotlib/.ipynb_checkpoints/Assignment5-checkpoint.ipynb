# %%
"""Name: Ashish Sameer Mulani
    PRN: 260240128007
    
    Name: Pranita Popat Lad
    PRN: 260240128028"""
# Out:
# 'Name: Ashish Sameer Mulani\n    PRN: 260240128007\n\n    Name: Pranita Popat Lad\n    PRN: 260240128028'

# %%
                                                #Assignment 4

# %%
'''Topic: Matplotlib

1.	Draw line chart to show urban and rural population of India over the years using population.csv 
    [rural 	population is the difference between total population and urban population]
Note: use appropriate labels, title and legend for each chart'''

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('population.csv')
df
# Out:
#     Year    Population Yearly % Change  Yearly Change  Median Age  \
# 0   1955  3.877009e+08           2.29%      8284413.0        19.7
# 1   1960  4.359903e+08           2.38%      9657890.0        19.2
# 2   1965  4.901401e+08           2.37%     10829962.0        18.5
# 3   1970  5.458643e+08           2.18%     11144824.0        18.1
# 4   1975  6.113095e+08           2.29%     13089053.0        18.4
# 5   1980  6.873540e+08           2.37%     15208898.0        18.9
# 6   1985  7.726478e+08           2.37%     17058754.0        19.3
# 7   1990  8.649722e+08           2.28%     18464886.0        19.7
# 8   1995  9.603010e+08           2.11%     19065765.0        20.3
# 9   2000  1.057923e+09           1.96%     19524338.0        21.2
# 10  2005  1.154676e+09           1.77%     19350718.0        22.2
# 11  2010  1.243482e+09           1.49%     17761048.0        23.6
# 12  2015  1.328024e+09           1.32%     16908587.0        25.3
# ...

# %%
df['Rural Population'] = df['Population'] - df['Urban Population']
df
# Out:
#     Year    Population Yearly % Change  Yearly Change  Median Age  \
# 0   1955  3.877009e+08           2.29%      8284413.0        19.7
# 1   1960  4.359903e+08           2.38%      9657890.0        19.2
# 2   1965  4.901401e+08           2.37%     10829962.0        18.5
# 3   1970  5.458643e+08           2.18%     11144824.0        18.1
# 4   1975  6.113095e+08           2.29%     13089053.0        18.4
# 5   1980  6.873540e+08           2.37%     15208898.0        18.9
# 6   1985  7.726478e+08           2.37%     17058754.0        19.3
# 7   1990  8.649722e+08           2.28%     18464886.0        19.7
# 8   1995  9.603010e+08           2.11%     19065765.0        20.3
# 9   2000  1.057923e+09           1.96%     19524338.0        21.2
# 10  2005  1.154676e+09           1.77%     19350718.0        22.2
# 11  2010  1.243482e+09           1.49%     17761048.0        23.6
# 12  2015  1.328024e+09           1.32%     16908587.0        25.3
# ...

# %%
df.dropna()
# Out:
#     Year    Population Yearly % Change  Yearly Change  Median Age  \
# 0   1955  3.877009e+08           2.29%      8284413.0        19.7
# 1   1960  4.359903e+08           2.38%      9657890.0        19.2
# 2   1965  4.901401e+08           2.37%     10829962.0        18.5
# 3   1970  5.458643e+08           2.18%     11144824.0        18.1
# 4   1975  6.113095e+08           2.29%     13089053.0        18.4
# 5   1980  6.873540e+08           2.37%     15208898.0        18.9
# 6   1985  7.726478e+08           2.37%     17058754.0        19.3
# 7   1990  8.649722e+08           2.28%     18464886.0        19.7
# 8   1995  9.603010e+08           2.11%     19065765.0        20.3
# 9   2000  1.057923e+09           1.96%     19524338.0        21.2
# 10  2005  1.154676e+09           1.77%     19350718.0        22.2
# 11  2010  1.243482e+09           1.49%     17761048.0        23.6
# 12  2015  1.328024e+09           1.32%     16908587.0        25.3
# ...

# %%
plt.plot(df['Year'], df['Rural Population'], color = "#F54927", lw=0.8, ls='--', label='Rural Population of India',marker='o')
plt.plot(df['Year'], df['Urban Population'], color = "#27F5E0", lw=0.8, ls='-.', label='Urban Population of India',marker='s')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.title('Rural Population Vs Urban Population over the years')
plt.show()

# %%
#2.Using a Bar chart display India's total and rural population from year 2020 to 2025

# %%
filt_df = df[(df['Year'] >= 2020) & (df['Year'] <= 2025)]
filt_df
# Out:
#     Year    Population Yearly % Change  Yearly Change  Median Age  \
# 13  2020  1.402618e+09           1.10%     14918639.0        27.0
# 14  2022  1.425423e+09           0.81%     11402759.0        27.7
# 15  2023  1.438070e+09           0.89%     12646384.0        28.1
# 16  2024  1.450936e+09           0.89%     12866195.0        28.4
# 17  2025  1.463866e+09           0.89%     12929734.0        28.8
#
#     Fertility Rate  Density Urban Pop %  Urban Population Country's Share  \
# 13            2.05      472      34.40%       483098640.0          17.78%
# 14            1.99      479      35.50%       506304869.0          17.77%
# 15            1.98      484      36.00%       518239122.0          17.77%
# 16            1.96      488      36.60%       530387142.0          17.78%
# 17            1.94      492      37.10%       542742539.0          17.78%
#
#     World Population  Rural Population
# 13      7.887001e+09       919519055.0
# 14      8.021407e+09       919118343.0
# ...

# %%
x_vals = np.arange(len(filt_df['Year']))
width=0.4
x_vals
# Out:
# array([0, 1, 2, 3, 4])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plt.bar(x_vals - width/2, filt_df['Population'],width=width, color = '#a86232', label='Total Population')
plt.bar(x_vals + width/2, filt_df['Rural Population'],width=width, color ='#324ca8', label='Rural Population')

plt.xlabel('Year')
plt.ylabel('Population')
plt.xticks(x_vals, filt_df['Year'])
plt.legend()
plt.title('Rural Population Vs Total Population')
plt.show()

# %%
#setting limit to ylable
fig, ax = plt.subplots(figsize=(10, 6))
x = np.arange(len(filt_df['Year']))
width = 0.35

ax.bar(x - width/2, filt_df['Population'], width, label='Population', color='royalblue')
ax.bar(x + width/2, filt_df['Rural Population'], width, label='Rural Population', color='forestgreen')

ax.set_ylim(800000000, 1500000000) 


ax.set_xticks(x)
ax.set_xticklabels(filt_df['Year'])
ax.set_ylabel('Population Count ', fontweight='bold')
ax.set_title('Population Trends', fontweight='bold')
ax.legend()

plt.show()

# %%
#2.	Using gapminder2007.csv show life expectancy of top 10 highly populated countries from Asia

# %%
df=pd.read_csv('gapminder2007.csv')
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
new_df = df[df['continent'] == 'Asia'].sort_values('pop',ascending=False).head(10)
new_df
# Out:
#          country         pop continent  lifeExp     gdpPercap
# 24         China  1318683096      Asia   72.961   4959.114854
# 58         India  1110396331      Asia   64.698   2452.210407
# 59     Indonesia   223547000      Asia   70.650   3540.651564
# 97      Pakistan   169270617      Asia   65.483   2605.947580
# 8     Bangladesh   150448339      Asia   64.062   1391.253792
# 66         Japan   127467972      Asia   82.603  31656.068060
# 101  Philippines    91077287      Asia   71.688   3190.481016
# 137      Vietnam    85262356      Asia   74.249   2441.576404
# 60          Iran    69453570      Asia   70.964  11605.714490
# 127     Thailand    65068149      Asia   70.616   7458.396327

# %%
plt.bar(new_df['country'], new_df['lifeExp'], width = 0.4, label ='Life Expectancy')
plt.xlabel('Country')
plt.xticks(rotation =90)
plt.legend()
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy of Top 10 Most Populated Countries')
plt.legend()
plt.show()

# %%
#3.	Using a pie chart show distribution of top six selling cars [Create data as required]

# %%
data = {'Car Model': ['Swift', 'Baleno', 'Nexon', 'WagonR', 'Creta', 'Punch'],
        'Sales': [18500, 17200, 15800, 15500, 14900, 14200]}
df = pd.DataFrame(data)
df
# Out:
#   Car Model  Sales
# 0     Swift  18500
# 1    Baleno  17200
# 2     Nexon  15800
# 3    WagonR  15500
# 4     Creta  14900
# 5     Punch  14200

# %%
plt.pie(df['Sales'], 
        labels=df['Car Model'],
        colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6'],
        shadow=True,
        startangle=140, 
        explode=[0, 0, 0, 0, 0.1,0],
        wedgeprops={'edgecolor':'Black'},
        autopct='%1.1f%%')

plt.title('Distribution Selling Car Models', fontsize=15, fontweight='bold')
plt.legend(df['Car Model'], title="Models", loc="center left", bbox_to_anchor=(1.5, 0, 0.5, 1))
plt.show()

# %%
#4.	Using Histogram show distribution of developers by their experience [use survey_data_sample.csv]

# %%
df = pd.read_csv('survey_results-sample.csv')
df
# Out:
#        ResponseId                 Age YearsCode     CompTotal  \
# 0               1     18-24 years old       NaN           NaN
# 1               2     25-34 years old        18  2.850000e+05
# 2               3     45-54 years old        27  2.500000e+05
# 3               4     25-34 years old        12  1.560000e+05
# 4               5     25-34 years old         6  1.320000e+06
# ...           ...                 ...       ...           ...
# 89179       89180     25-34 years old        20  2.000000e+05
# 89180       89181     18-24 years old         5           NaN
# 89181       89182   Prefer not to say        10           NaN
# 89182       89183  Under 18 years old         3           NaN
# 89183       89184     35-44 years old        17  3.300000e+09
#
#        ConvertedCompYearly
# 0                      NaN
# 1                 285000.0
# 2                 250000.0
# 3                 156000.0
# 4                  23456.0
# ...                    ...
# ...

# %%
df=df.dropna()
df
# Out:
#        ResponseId              Age YearsCode  CompTotal  ConvertedCompYearly
# 1               2  25-34 years old        18   285000.0             285000.0
# 2               3  45-54 years old        27   250000.0             250000.0
# 3               4  25-34 years old        12   156000.0             156000.0
# 4               5  25-34 years old         6  1320000.0              23456.0
# 5               6  35-44 years old        21    78000.0              96828.0
# ...           ...              ...       ...        ...                  ...
# 89162       89163  35-44 years old        30   250000.0              50719.0
# 89166       89167  18-24 years old         7  6500000.0              16917.0
# 89167       89168  18-24 years old         6  1300000.0              15752.0
# 89170       89171  25-34 years old        18    60000.0              64254.0
# 89171       89172  25-34 years old        20    57000.0              61041.0
#
# [47950 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plt.hist(df['YearsCode'], bins=50, color='#69b3a2', edgecolor='black',label ="Developers")

plt.title('Distribution of Developers by Experience (YearsCode)', fontweight='bold')
plt.xlabel('Years of Coding Experience')
plt.ylabel('Number of Developers')
plt.xticks(rotation =90)
plt.legend()

plt.show()
